# %% [markdown]
# # take a closer look into GSE's attributes

# %%
import concurrent.futures
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv
import re
import json
from tqdm import tqdm
import spacy

# %%
df_human = pd.read_json('data/metadata_human.json').transpose()
df_mouse = pd.read_json('data/metadata_mouse.json').transpose()

df = pd.concat([df_human, df_mouse])

df
# Out:
#                                                        Title  \
# GSE100027  Hit-and-run epigenetic editing prevents senesc...
# GSE100040  Human TFIIH kinase CDK7 regulates transcriptio...
# GSE100075  Discovery of naturally occurring ESR1 mutation...
# GSE100081  Mining the stiffness-sensitive transcriptome i...
# GSE100092  The E3 ubiquitin ligase HectD1 suppresses EMT ...
# ...                                                      ...
# GSE99973   Thiol-linked alkylation for the metabolic sequ...
# GSE99974   Thiol-linked alkylation for the metabolic sequ...
# GSE99975   Thiol-linked alkylation for the metabolic sequ...
# GSE99977   Thiol-linked alkylation for the metabolic sequ...
# GSE99989   Epidermal Wnt signaling regulates transcriptom...
#
#                                              Experiment type      Organism  \
# GSE100027  Expression profiling by high throughput sequen...  Homo sapiens
# GSE100040  Expression profiling by high throughput sequen...  Homo sapiens
# GSE100075  Expression profiling by high throughput sequen...  Homo sapiens
# GSE100081  Expression profiling by high throughput sequen...  Homo sapiens
# GSE100092  Expression profiling by high throughput sequen...  Homo sapiens
# ...                                                      ...           ...
# GSE99973   Expression profiling by high throughput sequen...  Mus musculus
# GSE99974   Expression profiling by high throughput sequen...  Mus musculus
# GSE99975   Expression profiling by high throughput sequen...  Mus musculus
# GSE99977   Expression profiling by high throughput sequen...  Mus musculus
# GSE99989   Expression profiling by high throughput sequen...  Mus musculus
#
#                                                      Summary  \
# GSE100027  Aberrant promoter DNA hypermethylation is a ha...
# GSE100040  CDK7 phosphorylates the RNA polymerase II (pol...
# GSE100075  We report the first discovery of naturally occ...
# GSE100081  Vascular extracellular matrix (ECM) stiffening...
# GSE100092  Cancer cells exploit the epithelial-to-mesench...
# ...                                                      ...
# GSE99973   Gene expression profiling by high-throughput s...
# GSE99974   Gene expression profiling by high-throughput s...
# GSE99975   Gene expression profiling by high-throughput s...
# GSE99977   Gene expression profiling by high-throughput s...
# GSE99989   We performed single-cell mRNA-Seq on wild-type...
#
#                                               Overall design        SRA  \
# GSE100027  RNA-seq experiment with n=3 biological replica...  SRP109188
# GSE100040  WT and analogue sensitive Cdk7as mutant cells ...  SRP109292
# GSE100075  RNAseq examination of gene expression changes ...  SRP109286
# GSE100081  4 unique sample types with 4 replicates (16 to...  SRP109287
# GSE100092  Differential gene expression profile following...  SRP109301
# ...                                                      ...        ...
# GSE99973   Wildtype (wt) mouse embryonic stem (mES) cells...  SRP109172
# GSE99974   Wildtype (wt) mouse embryonic stem (mES) cells...  SRP109093
# GSE99975   5 Âµg/ml Actinomycin D was added to wildtype m...  SRP109094
# GSE99977   Total RNA from wildtype mouse embryonic stem (...  SRP109095
# GSE99989   Comparison of cells exposed to Wnt activated n...  SRP109109
#
#                                                      Samples  \
# GSE100027  [GSM2668081, GSM2668082, GSM2668083, GSM266808...
# GSE100040  [GSM2670975, GSM2670976, GSM2670977, GSM267097...
# GSE100075  [GSM2670874, GSM2670875, GSM2670876, GSM267087...
# GSE100081  [GSM2670929, GSM2670930, GSM2670931, GSM267093...
# GSE100092  [GSM2671095, GSM2671096, GSM2671097, GSM267109...
# ...                                                      ...
# GSE99973   [GSM2666852, GSM2666853, GSM2666854, GSM266685...
# GSE99974   [GSM2666870, GSM2666871, GSM2666872, GSM266687...
# GSE99975   [GSM2666888, GSM2666889, GSM2666890, GSM266689...
# GSE99977   [GSM2666912, GSM2666913, GSM2666914, GSM266691...
# GSE99989   [GSM2667058, GSM2667059, GSM2667060, GSM266706...
#
#                                                    Platforms
# GSE100027     GPL20301\nIllumina HiSeq 4000 (Homo sapiens)\n
# GSE100040  GPL20301\nIllumina HiSeq 4000 (Homo sapiens)\n...
# GSE100075  GPL16791\nIllumina HiSeq 2500 (Homo sapiens)\n...
# GSE100081     GPL16791\nIllumina HiSeq 2500 (Homo sapiens)\n
# GSE100092     GPL11154\nIllumina HiSeq 2000 (Homo sapiens)\n
# ...                                                      ...
# GSE99973      GPL17021\nIllumina HiSeq 2500 (Mus musculus)\n
# GSE99974      GPL17021\nIllumina HiSeq 2500 (Mus musculus)\n
# GSE99975      GPL17021\nIllumina HiSeq 2500 (Mus musculus)\n
# GSE99977      GPL17021\nIllumina HiSeq 2500 (Mus musculus)\n
# GSE99989      GPL21103\nIllumina HiSeq 4000 (Mus musculus)\n
#
# [7461 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7461 entries, GSE100027 to GSE99989
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Title            7461 non-null   object
#  1   Experiment type  7461 non-null   object
#  2   Organism         7461 non-null   object
#  3   Summary          7461 non-null   object
#  4   Overall design   7461 non-null   object
#  5   SRA              7461 non-null   object
#  6   Samples          7461 non-null   object
#  7   Platforms        7461 non-null   object
# dtypes: object(8)
# memory usage: 524.6+ KB

# %%
unique_values = df['Experiment type'].unique()
print(unique_values)
# Out:
# ['Expression profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingNon-coding RNA profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingOther'
#  'Genome binding/occupancy profiling by high throughput sequencingExpression profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencingOther'
#  'Expression profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencingMethylation profiling by high throughput sequencing'
#  'Genome binding/occupancy profiling by high throughput sequencingExpression profiling by high throughput sequencingOther'
#  'Expression profiling by high throughput sequencingMethylation profiling by high throughput sequencing'
#  'OtherExpression profiling by high throughput sequencing'
#  'Experiment type not found on the page.'
#  'Expression profiling by arrayGenome variation profiling by genome tiling arrayExpression profiling by high throughput sequencing'
#  'Non-coding RNA profiling by high throughput sequencing'
#  'Genome binding/occupancy profiling by genome tiling arrayGenome binding/occupancy profiling by high throughput sequencingExpression profiling by high throughput sequencing'
#  'Non-coding RNA profiling by high throughput sequencingExpression profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencingNon-coding RNA profiling by high throughput sequencing'
#  'Other'
#  'Expression profiling by high throughput sequencingMethylation profiling by high throughput sequencingNon-coding RNA profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingMethylation profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencing'
#  'OtherExpression profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencing'
#  'Methylation profiling by high throughput sequencingExpression profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingNon-coding RNA profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingThird-party reanalysis'
#  'Expression profiling by high throughput sequencingMethylation profiling by high throughput sequencingOther'
#  'Expression profiling by high throughput sequencingNon-coding RNA profiling by high throughput sequencingOther'
#  'Expression profiling by high throughput sequencingNon-coding RNA profiling by high throughput sequencingThird-party reanalysis'
#  'OtherExpression profiling by high throughput sequencingMethylation profiling by high throughput sequencing'
#  'Methylation profiling by high throughput sequencingExpression profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencingMethylation profiling by high throughput sequencingOther'
#  'Genome variation profiling by high throughput sequencingExpression profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingOtherGenome binding/occupancy profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingNon-coding RNA profiling by high throughput sequencingMethylation profiling by high throughput sequencing'
#  'Genome binding/occupancy profiling by high throughput sequencingMethylation profiling by high throughput sequencingExpression profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingNon-coding RNA profiling by high throughput sequencingGenome variation profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingThird-party reanalysisGenome binding/occupancy profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingGenome variation profiling by high throughput sequencingOther'
#  'Non-coding RNA profiling by high throughput sequencingThird-party reanalysisExpression profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingGenome variation profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencingThird-party reanalysis'
#  'Expression profiling by high throughput sequencingOtherNon-coding RNA profiling by high throughput sequencing'
#  'Third-party reanalysisExpression profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencingGenome variation profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencingMethylation profiling by array'
#  'Genome binding/occupancy profiling by high throughput sequencingOtherExpression profiling by high throughput sequencing'
#  'OtherGenome binding/occupancy profiling by high throughput sequencingExpression profiling by high throughput sequencing'
#  'Genome binding/occupancy profiling by high throughput sequencingExpression profiling by high throughput sequencingMethylation profiling by high throughput sequencing'
#  'OtherExpression profiling by high throughput sequencingNon-coding RNA profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingNon-coding RNA profiling by array'
#  'Expression profiling by high throughput sequencingExpression profiling by arrayGenome binding/occupancy profiling by high throughput sequencing'
#  'Genome binding/occupancy profiling by high throughput sequencing'
#  'Non-coding RNA profiling by high throughput sequencingMethylation profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencing'
#  'Methylation profiling by high throughput sequencingExpression profiling by high throughput sequencingOther'
#  'Genome binding/occupancy profiling by high throughput sequencingThird-party reanalysisExpression profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingNon-coding RNA profiling by high throughput sequencingMethylation profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencingOther'
#  'Genome binding/occupancy profiling by high throughput sequencingExpression profiling by high throughput sequencingExpression profiling by array'
#  'Non-coding RNA profiling by high throughput sequencingExpression profiling by high throughput sequencingMethylation profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencingOtherNon-coding RNA profiling by high throughput sequencing'
#  'Genome binding/occupancy profiling by high throughput sequencingNon-coding RNA profiling by high throughput sequencingOtherExpression profiling by high throughput sequencing'
#  'Genome binding/occupancy profiling by high throughput sequencingNon-coding RNA profiling by high throughput sequencingExpression profiling by high throughput sequencing'
#  'Expression profiling by high throughput sequencingNon-coding RNA profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencingOther'
#  'Expression profiling by high throughput sequencingGenome binding/occupancy profiling by high throughput sequencingOtherMethylation profiling by high throughput sequencing']

# %%
value_to_check = 'Experiment type not found on the page.'

# Create a boolean mask to identify rows where the specified column has the desired value
mask = df['Experiment type'] == value_to_check

# Use the boolean mask to filter the DataFrame and get the rows where the condition is True
rows_with_value = df[mask]

# Display the rows where the specified column has the desired value
print(rows_with_value)
# Out:
#                                   Title  \
# GSE109702  Title not found on the page.
# GSE67934   Title not found on the page.
#
#                                   Experiment type  \
# GSE109702  Experiment type not found on the page.
# GSE67934   Experiment type not found on the page.
#
#                                   Organism                         Summary  \
# GSE109702  Organism not found on the page.  Summary not found on the page.
# GSE67934   Organism not found on the page.  Summary not found on the page.
#
#                                   Overall design                         SRA  \
# GSE109702  Overall design not found on the page.  SRA not found on the page.
# GSE67934   Overall design not found on the page.  SRA not found on the page.
#
#           Samples                         Platforms
# GSE109702      []  Platforms not found on the page.
# GSE67934       []  Platforms not found on the page.

# %% [markdown]
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE109702
# GSE67934
# were deleted so we drop these GSEs

# %%
df = df[~mask]
#reset the index after dropping rows
#df_human = df_human.reset_index(drop=True)

# %%
df.shape
# Out:
# (7459, 8)

# %%
mask = df.applymap(lambda x: "HeLa" in str(x))

# Use any() along axis=1 to check if the keyword is present in any cell of each row
rows_with_keyword = mask.any(axis=1)

# Filter the DataFrame based on the rows with the keyword
result_df = df[rows_with_keyword]

result_df
# Out:
#                                                        Title  \
# GSE100982  hMTR4 plays a central role in creating balance...
# GSE101518  Large-scale low-cost NGS library preparation u...
# GSE101519  Large-scale low-cost NGS library preparation u...
# GSE102893  An Mtr4/ZFC3H1 complex facilitates turnover of...
# GSE104736  Non-synchronized cell cycle transcriptomics in...
# ...                                                      ...
# GSE95455   Assessing the impact of the R252W Charcot-Mari...
# GSE96777   ZBTB48 is both a vertebrate telomere-binding p...
# GSE97009   Widespread activation of antisense transcripti...
# GSE97725   Episomal S/MAR-based replicons do not alter ex...
# GSE99059   ARS2 is a general suppressor of pervasive tran...
#
#                                              Experiment type      Organism  \
# GSE100982  Expression profiling by high throughput sequen...  Homo sapiens
# GSE101518  Expression profiling by high throughput sequen...  Homo sapiens
# GSE101519  Expression profiling by high throughput sequen...  Homo sapiens
# GSE102893  Expression profiling by high throughput sequen...  Homo sapiens
# GSE104736  Expression profiling by high throughput sequen...  Homo sapiens
# ...                                                      ...           ...
# GSE95455   Expression profiling by high throughput sequen...  Homo sapiens
# GSE96777   Expression profiling by high throughput sequen...  Homo sapiens
# GSE97009   Expression profiling by high throughput sequen...  Homo sapiens
# GSE97725   Expression profiling by high throughput sequen...  Homo sapiens
# GSE99059   Expression profiling by high throughput sequen...  Homo sapiens
#
#                                                      Summary  \
# GSE100982  To examine whether the competition between hMT...
# GSE101518  In recent years, tagmentation-based library pr...
# GSE101519  In recent years, tagmentation-based library pr...
# GSE102893  Many long noncoding RNAs (lncRNAs) are unstabl...
# GSE104736  Sorting U2OS and HeLa cells genetically modifi...
# ...                                                      ...
# GSE95455   HeLa cells lacking MORC2 generated through CRI...
# GSE96777   Here we show that ZBTB48 binds directly both t...
# GSE97009   We show that Herpes simplex virus 1 (HSV-1) in...
# GSE97725   Methods: mRNA profiles of untransfected HeLa c...
# GSE99059   Termination of transcription is important for ...
#
#                                               Overall design        SRA  \
# GSE100982  rRNA-depleted RNAs isolated from control, ALYR...  SRP111407
# GSE101518  For samples labeled i5i7, full-length cDNA was...  SRP112552
# GSE101519  For samples labeled polyA, full-length cDNA wa...  SRP112553
# GSE102893  3'READS of siMtr4, siRBM7, siZCCHC8 and siCont...  SRP115916
# GSE104736  HeLa cells were sorted at three timepoints, wh...  SRP119610
# ...                                                      ...        ...
# GSE95455   Total RNA-seq of MORC2 knockout cells, either ...  SRP100835
# GSE96777   ZBTB48 WT clones were generated by single sort...  SRP102096
# GSE97009   Human WI-38 and HeLa cells were infected with ...  SRP102444
# GSE97725   Examination of mRNA profiles in two different ...  SRP103855
# GSE99059   RNA from HeLa cells was analysed by next gener...  SRP107322
#
#                                                      Samples  \
# GSE100982   [GSM2698456, GSM2698457, GSM2698458, GSM2698459]
# GSE101518  [GSM2705279, GSM2705280, GSM2705281, GSM270528...
# GSE101519  [GSM2705324, GSM2705325, GSM2705326, GSM270532...
# GSE102893   [GSM2747880, GSM2747881, GSM2747882, GSM2747883]
# GSE104736  [GSM2806897, GSM2806898, GSM2806899, GSM280690...
# ...                                                      ...
# GSE95455                [GSM2514492, GSM2514493, GSM2514494]
# GSE96777   [GSM2543167, GSM2543168, GSM2543169, GSM254317...
# GSE97009   [GSM2549749, GSM2549750, GSM2549751, GSM254975...
# GSE97725                            [GSM2576185, GSM2576186]
# GSE99059   [GSM2631679, GSM2631680, GSM2631681, GSM263168...
#
#                                                    Platforms
# GSE100982             GPL20795\nHiSeq X Ten (Homo sapiens)\n
# GSE101518    GPL18573\nIllumina NextSeq 500 (Homo sapiens)\n
# GSE101519    GPL18573\nIllumina NextSeq 500 (Homo sapiens)\n
# GSE102893     GPL11154\nIllumina HiSeq 2000 (Homo sapiens)\n
# GSE104736     GPL11154\nIllumina HiSeq 2000 (Homo sapiens)\n
# ...                                                      ...
# GSE95455      GPL16791\nIllumina HiSeq 2500 (Homo sapiens)\n
# GSE96777      GPL16791\nIllumina HiSeq 2500 (Homo sapiens)\n
# GSE97009   GPL11154\nIllumina HiSeq 2000 (Homo sapiens)\n...
# GSE97725     GPL18573\nIllumina NextSeq 500 (Homo sapiens)\n
# GSE99059      GPL20301\nIllumina HiSeq 4000 (Homo sapiens)\n
#
# [110 rows x 8 columns]

# %%
condition_organism = df['Organism'] == 'Mus musculus'
condition_keyword = df.applymap(lambda x: "cancer" in str(x)).any(axis=1)

result_df_mouse = df[condition_organism & condition_keyword]
result_df_mouse
# Out:
#                                                        Title  \
# GSE100276  Epigenetic memory of obesity predisposes to co...
# GSE100406  Binding of High Mobility Group A proteins to t...
# GSE100771  cGAS surveillance of micronuclei links genome ...
# GSE101859  The RhoJ-BAD Signaling Network: An Achilles He...
# GSE102345  Whole tumor RNA-sequencing and deconvolution r...
# ...                                                      ...
# GSE98860                         Mtor knockout in PDAC cells
# GSE98960   Epigenetic restriction of embryonic and extrae...
# GSE99101   Enhancer-binding of Brd4 controls cell differe...
# GSE99364   Stabilization of c-Myc protein by CAMKIIÎ³ pro...
# GSE99808   Transient activation of tumor-associated macro...
#
#                                              Experiment type      Organism  \
# GSE100276  Expression profiling by high throughput sequen...  Mus musculus
# GSE100406  Expression profiling by high throughput sequen...  Mus musculus
# GSE100771  Expression profiling by high throughput sequen...  Mus musculus
# GSE101859  Expression profiling by high throughput sequen...  Mus musculus
# GSE102345  Expression profiling by high throughput sequen...  Mus musculus
# ...                                                      ...           ...
# GSE98860   Expression profiling by high throughput sequen...  Mus musculus
# GSE98960   Expression profiling by high throughput sequen...  Mus musculus
# GSE99101   Expression profiling by high throughput sequen...  Mus musculus
# GSE99364   Expression profiling by high throughput sequen...  Mus musculus
# GSE99808   Expression profiling by high throughput sequen...  Mus musculus
#
#                                                      Summary  \
# GSE100276  Colorectal cancer (CRC) is the third most comm...
# GSE100406  High mobility group (HMG) proteins are of simi...
# GSE100771  DNA is strictly compartmentalised within the n...
# GSE101859  Genes and pathways that allow cells to cope wi...
# GSE102345  The concept that solid tumors are maintained b...
# ...                                                      ...
# GSE98860   A pancreatic ductal adenocarcinoma cell line w...
# GSE98960   Concerted efforts over past decades have estab...
# GSE99101   The epigenomic reader Brd4 is an important dru...
# GSE99364   Although high c-Myc protein expression is obse...
# GSE99808   Depletion of immunosuppressive tumor-associate...
#
#                                               Overall design        SRA  \
# GSE100276  Ribo-zero RNA-Seq was performed in colonic epi...  SRP109869
# GSE100406  RNA-seq was performed in WT, Hmga1 KO and Hmga...  SRP110243
# GSE100771  RNA-seq of 35 individual mouse embryonic fibro...  SRP111009
# GSE101859  5 Braf CA/+; Pten fl/+; Cre +; RhoJ +/+ melano...  SRP113541
# GSE102345  We profiled homogenized optic nerve, optic gli...  SRP114994
# ...                                                      ...        ...
# GSE98860   Tamoxifen induced knockout of Mtor in a Pdx1-F...  SRP106986
# GSE98960   Comparison of gene expression patterns in Extr...  SRP107205
# GSE99101   Expression profiling by RNA-seq, and profiling...  SRP107492
# GSE99364   We investigated how deleting CAMKIIÎ³ suppress...  SRP108130
# GSE99808   Female C57BL/6N mice (6-8 weeks in age, obtain...  SRP108832
#
#                                                      Samples  \
# GSE100276  [GSM2676966, GSM2676967, GSM2676968, GSM267696...
# GSE100406  [GSM2680435, GSM2680436, GSM2680437, GSM268043...
# GSE100771  [GSM2693064, GSM2693065, GSM2693066, GSM269306...
# GSE101859  [GSM2717318, GSM2717319, GSM2717320, GSM271732...
# GSE102345  [GSM2735070, GSM2735071, GSM2735072, GSM273507...
# ...                                                      ...
# GSE98860    [GSM2616852, GSM2616853, GSM2616854, GSM2616855]
# GSE98960   [GSM2628310, GSM2628311, GSM2628312, GSM262831...
# GSE99101   [GSM2633453, GSM2633454, GSM2633455, GSM263345...
# GSE99364    [GSM2643072, GSM2643073, GSM2643074, GSM2643075]
# GSE99808   [GSM2653206, GSM2653207, GSM2653208, GSM265320...
#
#                                                    Platforms
# GSE100276    GPL19057\nIllumina NextSeq 500 (Mus musculus)\n
# GSE100406     GPL17021\nIllumina HiSeq 2500 (Mus musculus)\n
# GSE100771             GPL21626\nNextSeq 550 (Mus musculus)\n
# GSE101859     GPL17021\nIllumina HiSeq 2500 (Mus musculus)\n
# GSE102345  GPL17021\nIllumina HiSeq 2500 (Mus musculus)\n...
# ...                                                      ...
# GSE98860      GPL13112\nIllumina HiSeq 2000 (Mus musculus)\n
# GSE98960      GPL17021\nIllumina HiSeq 2500 (Mus musculus)\n
# GSE99101      GPL17021\nIllumina HiSeq 2500 (Mus musculus)\n
# GSE99364      GPL13112\nIllumina HiSeq 2000 (Mus musculus)\n
# GSE99808      GPL17021\nIllumina HiSeq 2500 (Mus musculus)\n
#
# [261 rows x 8 columns]

# %% [markdown]
# https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSM2676351
# if characterstic contains "cell line", then classify it as cell line study
#
# Source name	colonic epithelium
# Characteristics	strain: C57BL/6
# tissue: colon
# diet: 10% fat diet (LF)
#
# set condition, if source name is not cell line/ does not contain "cell line" && characteristics contain tissue, then classify it as tissue samples

# %%
tissue_keyword = df.applymap(lambda x: "colonic epithelium" in str(x)).any(axis=1)

result_df = df[tissue_keyword]

result_df
# Out:
#                                                        Title  \
# GSE62520   RNA-sequencing of mRNAs from control and CAP-D...
# GSE100276  Epigenetic memory of obesity predisposes to co...
# GSE63256   Reg4+ Deep Crypt Secretory cells function as e...
# GSE85731   Epigenetic memory of obesity in mouse colonic ...
# GSE86111   Time course profiling of IEC and total colonic...
#
#                                              Experiment type      Organism  \
# GSE62520   Expression profiling by high throughput sequen...  Homo sapiens
# GSE100276  Expression profiling by high throughput sequen...  Mus musculus
# GSE63256   Expression profiling by high throughput sequen...  Mus musculus
# GSE85731   Expression profiling by high throughput sequen...  Mus musculus
# GSE86111   Expression profiling by high throughput sequen...  Mus musculus
#
#                                                      Summary  \
# GSE62520   BACKGROUND & AIMS- More frequent interaction o...
# GSE100276  Colorectal cancer (CRC) is the third most comm...
# GSE63256   Lgr5+ stem cells reside at crypt bottoms of th...
# GSE85731   Colorectal cancer is the third most common can...
# GSE86111   In this experiment we profiled the transcripto...
#
#                                               Overall design        SRA  \
# GSE62520   Three RNA samples from 3 independent experimen...  SRP049063
# GSE100276  Ribo-zero RNA-Seq was performed in colonic epi...  SRP109869
# GSE63256   To define a global gene expression signature o...  SRP049774
# GSE85731   Whole-genome bisulfite sequencing, bisulfite P...  SRP082360
# GSE86111   Groups of three mice were inoculated with 2x10...  SRP083074
#
#                                                      Samples  \
# GSE62520   [GSM1528198, GSM1528199, GSM1528200, GSM152820...
# GSE100276  [GSM2676966, GSM2676967, GSM2676968, GSM267696...
# GSE63256    [GSM1544527, GSM1544528, GSM1544529, GSM1544530]
# GSE85731   [GSM2283268, GSM2283269, GSM2283270, GSM228327...
# GSE86111   [GSM2293852, GSM2293853, GSM2293854, GSM229385...
#
#                                                    Platforms
# GSE62520      GPL16791\nIllumina HiSeq 2500 (Homo sapiens)\n
# GSE100276    GPL19057\nIllumina NextSeq 500 (Mus musculus)\n
# GSE63256      GPL17021\nIllumina HiSeq 2500 (Mus musculus)\n
# GSE85731   GPL13112\nIllumina HiSeq 2000 (Mus musculus)\n...
# GSE86111      GPL13112\nIllumina HiSeq 2000 (Mus musculus)\n

# %%
cancer_cell_line_keyword = df.applymap(lambda x: "HepG2" in str(x)).any(axis=1)

result_df = df[cancer_cell_line_keyword]

result_df
# Out:
#                                                        Title  \
# GSE100210  RNA editing by ADAR1 leads to context-dependen...
# GSE102560  Cooperative and Antagonistic Transcriptional R...
# GSE108366  RNA-seq Facilitates Quantitative Analysis of W...
# GSE109072  Toxicogenomics of the flame retardant tris (2-...
# GSE109140  Valproic acid attenuates hyperglycemia induced...
# GSE109463  A toxicogenomics approach to screen chlorinate...
# GSE35464   Genome-wide analysis of histone methylation re...
# GSE36242   Transcriptomic response to benzo[a]pyrene trea...
# GSE37001                            METTL3 KD in HepG2 cells
# GSE37002          m6A mapping in human RNA (with treatments)
# GSE37003                m6A mapping in human RNA (untreated)
# GSE38447   Cell type-specific binding patterns reveal tha...
# GSE38886   Targeted RT-PCR assays spanning unannotated sp...
# GSE40069   The Small Molecule Genistein Increases Hepcidi...
# GSE41074   Next Generation Sequencing Facilitates Quantit...
# GSE47997   Global regulation of alternative splicing by a...
# GSE53292   Transcriptomic analysis of Plasmodium PBANKA, ...
# GSE79463   NR2E3 gene networks are associated with AHR si...
# GSE80361   Transcriptome profile of HepG2-expressing ATP7...
# GSE82110   Acriflavine inhibits the epithelial-to-mesench...
# GSE83321   Next Generation Sequencing Analysis of control...
# GSE83551                    RNA-seq in HepG2 and IMR90 cells
# GSE83577   Genome-wide Transcriptome Analysis of CD36 Ove...
# GSE87240   S-adenosyl-methionine treatment selectively bl...
# GSE89701   Whole-transcriptome maps of HepG2 cells after ...
# GSE93831   mRNA Profiling of miR-17 family inhibition usi...
# GSE98091   Transcriptomic analysis of the HOTAIR-regulate...
#
#                                              Experiment type      Organism  \
# GSE100210  Expression profiling by high throughput sequen...  Homo sapiens
# GSE102560  Expression profiling by high throughput sequen...  Homo sapiens
# GSE108366  Expression profiling by high throughput sequen...  Homo sapiens
# GSE109072  Expression profiling by high throughput sequen...  Homo sapiens
# GSE109140  Expression profiling by high throughput sequen...  Homo sapiens
# GSE109463  Expression profiling by high throughput sequen...  Homo sapiens
# GSE35464   Expression profiling by high throughput sequen...  Homo sapiens
# GSE36242   Expression profiling by high throughput sequen...  Homo sapiens
# GSE37001   Expression profiling by high throughput sequen...  Homo sapiens
# GSE37002   Expression profiling by high throughput sequen...  Homo sapiens
# GSE37003   Expression profiling by high throughput sequen...  Homo sapiens
# GSE38447   Expression profiling by high throughput sequen...  Homo sapiens
# GSE38886   Expression profiling by high throughput sequen...  Homo sapiens
# GSE40069   Expression profiling by high throughput sequen...  Homo sapiens
# GSE41074   Non-coding RNA profiling by high throughput se...  Homo sapiens
# GSE47997   Expression profiling by high throughput sequen...  Homo sapiens
# GSE53292   Expression profiling by high throughput sequen...  Homo sapiens
# GSE79463   Expression profiling by high throughput sequen...  Homo sapiens
# GSE80361   Expression profiling by high throughput sequen...  Homo sapiens
# GSE82110   Expression profiling by high throughput sequen...  Homo sapiens
# GSE83321   Expression profiling by high throughput sequen...  Homo sapiens
# GSE83551   Expression profiling by high throughput sequen...  Homo sapiens
# GSE83577   Expression profiling by high throughput sequen...  Homo sapiens
# GSE87240   Expression profiling by high throughput sequen...  Homo sapiens
# GSE89701   Expression profiling by high throughput sequen...  Homo sapiens
# GSE93831   Expression profiling by high throughput sequen...  Homo sapiens
# GSE98091   Expression profiling by high throughput sequen...  Homo sapiens
#
#                                                      Summary  \
# GSE100210  Adenosine deaminase acting on RNA 1 (ADAR1) is...
# GSE102560  We monitored the transcription changes associa...
# GSE108366  The goals of this study are to check mRNA leve...
# GSE109072  Tris (2-butoxyethyl) phosphate (TBOEP) is a co...
# GSE109140  Diabetes is a multifactorial disorder and epig...
# GSE109463  Tris(2-chloroethyl) phosphate (TCEP) is a perv...
# GSE35464   Hepatitis B virus (HBV) is a hepatotropic viru...
# GSE36242   Whole-genome transcriptome measurements are pi...
# GSE37001   To gain insight into possible processes that r...
# GSE37002   We developed a novel approach, m6A-seq, for hi...
# GSE37003   We developed a novel approach, m6A-seq, for hi...
# GSE38447   The TCF7L2 transcription factor is linked to a...
# GSE38886   The ENCODE projects seeks to identify and char...
# GSE40069   Hepcidin, a peptide hormone that decreases int...
# GSE41074   To explore functionally crucial tumor-suppress...
# GSE47997   Alternative mRNA splicing is a major mechanism...
# GSE53292   Liver stage of malaria parasite exports SLTRiP...
# GSE79463   In order to identify NR2E3-specific gene expre...
# GSE80361   In order to identify the effects of JNK inhibi...
# GSE82110   Background: Epithelial-to-mesenchymal transiti...
# GSE83321   we treated the HepG2 cells with low concentrat...
# GSE83551   Expression analysis in HepG2 and IMR90 cells i...
# GSE83577   To understand the molecular basis underlying t...
# GSE87240   S-adenosyl methionine (SAM) is a ubiquitous me...
# GSE89701   Cationic liposomes (CLs) are non-viral vectors...
# GSE93831   To functionally characterize the role of miR-1...
# GSE98091   An integrated RNA sequencing transcriptomic an...
#
#                                               Overall design        SRA  \
# GSE100210  Examination of control and ADAR1 KD HepG2 cell...  SRP109827
# GSE102560  Cells were transduced with shRNA targeting the...  SRP115304
# GSE108366  Examination of 2 different mRNA profiles in 2 ...  SRP121524
# GSE109072  HepG2 cells were treated with low (2.5 uM) or ...  SRP128876
# GSE109140  RNA-seq was performed to understand gene expre...  SRP128998
# GSE109463  HepG2 cells were treated with low (25 uM) or h...  SRP131103
# GSE35464   A large-scale analysis of gene expression of 2...  SRP010670
# GSE36242   Examination of 2 biological replicates at 2 di...  SRP011233
# GSE37001   Differential expression analysis of METTL3 KD ...  SRP012096
# GSE37002   Identification of m6A modified sequences in He...  SRP012098
# GSE37003   Identification of m6A modified sequences in He...  SRP012099
# GSE38447   RNAseq analysis of MCF7 cells transfected with...  SRP013504
# GSE38886         454 Data from HepG2, HUVEC, and H1 ES cells  SRP013872
# GSE40069   RNA-seq of HepG2 cells treated with DMSO 1%, B...  SRP014790
# GSE41074   Deep sequencing of RNAs in Ago2-IP fraction an...  SRP015845
# GSE47997   HepG2 and K562 cell lines were stably transfec...  SRP026084
# GSE53292   mRNA profiles of Plasmodium PBANKA, PBSLTRiP-K...  SRP034011
# GSE79463   Two groups of samples are included: 1. sh cont...  SRP072131
# GSE80361   Transcriptome analysis of the hepatocytes over...  SRP073426
# GSE82110   Three conditions were investigated: (1) untrea...  SRP075963
# GSE83321   HepG2 cells mRNA profiles of Control and DEHP ...  SRP076513
# GSE83551   Transfect siRNA - extract RNA 72 hrs post tran...  SRP076842
# GSE83577   To better understand the molecular changes in ...  SRP076864
# GSE87240   RNA from control and SAM treated 3 cell lines:...  SRP090311
# GSE89701   Examination of gene expression level in CLs tr...  SRP093311
# GSE93831   Methods: HepG2 and SK-Hep1 HCC cell lines were...  SRP097126
# GSE98091   Examine the overall transcriptomic changes in ...  SRP105050
#
#                                                      Samples  \
# GSE100210  [GSM2676351, GSM2676352, GSM2676353, GSM267635...
# GSE102560  [GSM2740942, GSM2740943, GSM2740944, GSM274094...
# GSE108366                           [GSM2896229, GSM2896230]
# GSE109072  [GSM2931164, GSM2931165, GSM2931166, GSM293116...
# GSE109140  [GSM2932791, GSM2932792, GSM2932793, GSM293279...
# GSE109463  [GSM2943835, GSM2943836, GSM2943837, GSM294383...
# GSE35464                              [GSM869015, GSM869016]
# GSE36242   [GSM884981, GSM884982, GSM884983, GSM884984, G...
# GSE37001        [GSM908325, GSM908326, GSM908327, GSM908328]
# GSE37002   [GSM908329, GSM908330, GSM908331, GSM908332, G...
# GSE37003   [GSM908337, GSM908338, GSM908339, GSM908340, G...
# GSE38447   [GSM942209, GSM942210, GSM942211, GSM946849, G...
# GSE38886                   [GSM951481, GSM951482, GSM951483]
# GSE40069   [GSM984644, GSM984645, GSM984646, GSM984647, G...
# GSE41074   [GSM1008241, GSM1008242, GSM1008243, GSM100824...
# GSE47997    [GSM1164649, GSM1164650, GSM1164651, GSM1164652]
# GSE53292    [GSM1289018, GSM1289019, GSM1289020, GSM1289021]
# GSE79463    [GSM2095704, GSM2095705, GSM2095706, GSM2095707]
# GSE80361   [GSM2125267, GSM2125268, GSM2125269, GSM212527...
# GSE82110   [GSM2183589, GSM2183590, GSM2183591, GSM218359...
# GSE83321                            [GSM2199507, GSM2199508]
# GSE83551   [GSM2209494, GSM2209495, GSM2209496, GSM220949...
# GSE83577   [GSM2209815, GSM2209816, GSM2209817, GSM220981...
# GSE87240   [GSM2326084, GSM2326085, GSM2326086, GSM232608...
# GSE89701   [GSM2387014, GSM2387015, GSM2387016, GSM238701...
# GSE93831   [GSM2463218, GSM2463219, GSM2463220, GSM246322...
# GSE98091   [GSM2586967, GSM2586968, GSM2586969, GSM258697...
#
#                                                    Platforms
# GSE100210     GPL16791\nIllumina HiSeq 2500 (Homo sapiens)\n
# GSE102560     GPL20301\nIllumina HiSeq 4000 (Homo sapiens)\n
# GSE108366  GPL10999\nIllumina Genome Analyzer IIx (Homo s...
# GSE109072     GPL18460\nIllumina HiSeq 1500 (Homo sapiens)\n
# GSE109140     GPL16791\nIllumina HiSeq 2500 (Homo sapiens)\n
# GSE109463     GPL18460\nIllumina HiSeq 1500 (Homo sapiens)\n
# GSE35464      GPL11154\nIllumina HiSeq 2000 (Homo sapiens)\n
# GSE36242   GPL9052\nIllumina Genome Analyzer (Homo sapien...
# GSE37001   GPL10999\nIllumina Genome Analyzer IIx (Homo s...
# GSE37002   GPL10999\nIllumina Genome Analyzer IIx (Homo s...
# GSE37003   GPL10999\nIllumina Genome Analyzer IIx (Homo s...
# GSE38447      GPL11154\nIllumina HiSeq 2000 (Homo sapiens)\n
# GSE38886                GPL9186\n454 GS FLX (Homo sapiens)\n
# GSE40069   GPL9115\nIllumina Genome Analyzer II (Homo sap...
# GSE41074   GPL10999\nIllumina Genome Analyzer IIx (Homo s...
# GSE47997   GPL10999\nIllumina Genome Analyzer IIx (Homo s...
# GSE53292   GPL10999\nIllumina Genome Analyzer IIx (Homo s...
# GSE79463      GPL15433\nIllumina HiSeq 1000 (Homo sapiens)\n
# GSE80361      GPL15433\nIllumina HiSeq 1000 (Homo sapiens)\n
# GSE82110     GPL18573\nIllumina NextSeq 500 (Homo sapiens)\n
# GSE83321       GPL17303\nIon Torrent Proton (Homo sapiens)\n
# GSE83551      GPL16791\nIllumina HiSeq 2500 (Homo sapiens)\n
# GSE83577       GPL17303\nIon Torrent Proton (Homo sapiens)\n
# GSE87240      GPL11154\nIllumina HiSeq 2000 (Homo sapiens)\n
# GSE89701       GPL17303\nIon Torrent Proton (Homo sapiens)\n
# GSE93831      GPL11154\nIllumina HiSeq 2000 (Homo sapiens)\n
# GSE98091      GPL11154\nIllumina HiSeq 2000 (Homo sapiens)\n

# %% [markdown]
# ATCC cell lines: https://www.atcc.org/
#
#     Hepa 1-6: https://www.atcc.org/products/crl-1830
#
#     Hep G2 [HEPG2]: https://www.atcc.org/products/hb-8065
#
# Cellosaurus - a knowledge resource on cell lines:
# https://www.cellosaurus.org/index.html

# %%
cancer_cell_line_keywords = ['Hepa1-6','Hepa 1-6', 'TIB-75', 'BNL 1ME A.7R.1', 'Hep 55.1C', 'Hep-55.1C', '55.1C']

cancer_cell_line_keyword = df.applymap(lambda x: any(keyword in str(x) for keyword in cancer_cell_line_keywords)).any(axis=1)


result_df = df[cancer_cell_line_keyword]

result_df

# Hepa1-6 cells
# Out:
#                                                       Title  \
# GSE87511  Dietary interventions modulate global non-codi...
#
#                                             Experiment type      Organism  \
# GSE87511  Expression profiling by high throughput sequen...  Mus musculus
#
#                                                     Summary  \
# GSE87511  Using high-throughput deep sequencing we profi...
#
#                                              Overall design        SRA  \
# GSE87511  Mouse Hepa1-6 cells were treated with lentivir...  SRP090682
#
#                                                    Samples  \
# GSE87511  [GSM2332931, GSM2332932, GSM2332933, GSM2332934]
#
#                                                Platforms
# GSE87511  GPL17021\nIllumina HiSeq 2500 (Mus musculus)\n

# %%
# Load the English language model
nlp = spacy.load("en_core_sci_sm")

#en_core_web_sm

text = """
To define a global gene expression signature of DCS cells, we performed RNA-sequencing (RNA-seq) of sorted Reg4-dsRed+ and Lgr5-GFP+ cells from colonic epithelium.
Sorting and RNA-seq library preparation was performed twice, to obtain a biological replicate.

Examination of control and ADAR1 KD HepG2 cells using PARSseq method in order to find changes in RNA 2D structure induced by A-to-I RNA editing. 
We used PARSseq for HepG2 control and ADAR KD cells in two replicates with S1/V1 nucleases treatment for each ((control+KD)*2*2= 8 PARSseq samples). We used RNAseq of HepG2 control and ADAR KD cells with additional Ribo-seq (control and ADAR KD in 2 replicates=4 Ribo-seq samples) to further confirm the changes we observed in the PARSseq experiment.
"""

# Process the text using spaCy
doc = nlp(text)

entities = [(ent.text, ent.label_) for ent in doc.ents]

# expecting:  Reg4-dsRed+, Lgr5-GFP+, HepG2
print(entities)
# Out:
# /Users/xbi/.conda/envs/env/lib/python3.11/site-packages/spacy/language.py:2141: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]
# [('global', 'ENTITY'), ('gene expression', 'ENTITY'), ('DCS cells', 'ENTITY'), ('RNA-sequencing', 'ENTITY'), ('RNA-seq', 'ENTITY'), ('sorted Reg4-dsRed+', 'ENTITY'), ('Lgr5-GFP+ cells', 'ENTITY'), ('colonic epithelium', 'ENTITY'), ('Sorting', 'ENTITY'), ('RNA-seq library', 'ENTITY'), ('preparation', 'ENTITY'), ('biological', 'ENTITY'), ('replicate', 'ENTITY'), ('ADAR1 KD', 'ENTITY'), ('HepG2 cells', 'ENTITY'), ('PARSseq method', 'ENTITY'), ('RNA', 'ENTITY'), ('2D structure', 'ENTITY'), ('induced', 'ENTITY'), ('A-to-I RNA', 'ENTITY'), ('PARSseq', 'ENTITY'), ('HepG2', 'ENTITY'), ('ADAR', 'ENTITY'), ('replicates', 'ENTITY'), ('S1/V1 nucleases', 'ENTITY'), ('treatment', 'ENTITY'), ('(control+KD)*2*2=', 'ENTITY'), ('PARSseq', 'ENTITY'), ('samples', 'ENTITY'), ('RNAseq', 'ENTITY'), ('HepG2 control', 'ENTITY'), ('ADAR', 'ENTITY'), ('Ribo-seq', 'ENTITY'), ('control', 'ENTITY'), ('Ribo-seq', 'ENTITY'), ('samples', 'ENTITY'), ('changes', 'ENTITY'), ('PARSseq', 'ENTITY'), ('experiment', 'ENTITY')]

# %%
# List of known cell lines
known_cell_lines = ["HepG2"]

def classify_cell_line(entity_text, known_cell_lines):
    """ classify cell line entities"""
    for cell_line in known_cell_lines:
        if cell_line.lower() in entity_text.lower():
            return f"{entity_text} is a {cell_line} cell line"
    return f"{entity_text} is not recognized as a known cell line"

# Filter entities related to cell lines based on keywords
cell_line_entities = [ent.text for ent in doc.ents if 'cell' in ent.text.lower()]

# Classify cell line entities
classified_entities = [classify_cell_line(entity, known_cell_lines) for entity in cell_line_entities]

print(classified_entities)
# Out:
# ['DCS cells is not recognized as a known cell line', 'Lgr5-GFP+ cells is not recognized as a known cell line', 'HepG2 cells is a HepG2 cell line']
